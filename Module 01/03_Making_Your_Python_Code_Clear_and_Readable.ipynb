# %% [markdown]
# <a href="https://colab.research.google.com/github/ilyeoncz/ISYS2001/blob/main/Module%2001/03_Making_Your_Python_Code_Clear_and_Readable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Writing Code Someone Else Can Read
#
# Getting Python to run is only half the job. The other half is making your code — and your output — something a human can actually follow. A wall of unbroken text is just as hard to read as a wall of unbroken code.
#
# In this notebook you'll pick up three small habits:
#
# - Using blank lines to give your output room to breathe
# - Printing multiple lines from a single `print()` call
# - Writing comments that explain *why*, not just *what*
#
# None of this changes what your program does. It changes whether the next person reading it — including you, in six months — can make sense of it in ten seconds instead of ten minutes.
#
# Use your AI assistant as much as you like in this notebook, but the real goal isn't just finishing each exercise — it's understanding how `print()` actually behaves. That understanding is what lets you tell whether an AI's suggestion is actually good, or just confident-sounding.
#
# ## Section 10: A Blank Line in Your Code Does Nothing
#
# An empty line *in your code* has no effect on the output — Python just skips straight over it. For example:
#
# ```python
# print("Apple")
#
# print("or Orange?")
# ```
#
# **Output:**
# ```
# Apple
# or Orange?
# ```
#
# Guess what the cell below will print, then run it and check.

# %%
print("How")

print("are")
print("you?")
# Out:
# How
# are
# you?

# %% [markdown]
# > *Hint:* Every `print()` starts a new line, whether or not there's a blank line in your code above it.
#
# ## Section 11: A Blank Line in Your Output Takes Work
#
# So how do you get an actual blank line to show up in the output? Call `print()` with nothing inside it:
#
# ```python
# print("How")
# print()
# print("are")
# print("you?")
# ```
#
# **Output:**
# ```
# How
#
# are
# you?
# ```
#
# Notice that second, empty line — that's what `print()` on its own does.
#
# **Your task:** Rearrange the following lines to print:
#
# ```
# Blank spaces matter
# for clarity
#
# and style!
# ```
#
# > *Advanced tip:* Work out the order first, then figure out where the empty `print()` needs to sit.
#
# ## Section 12: Multiple Lines, One Function
#
# Can a single `print()` call produce several lines? Yes — two tricks do this.
#
# **Trick one: `\n` starts a new line**
#
# ```python
# print("This is the first line.\nThis is the second line.")
# ```
#
# **Output:**
# ```
# This is the first line.
# This is the second line.
# ```
#
# `\n` inside a string tells Python "jump to a new line here and keep printing." Simple, and useful when the whole thing is one string.
#
# > *Tip:* Reach for `\n` when you're building a message inside a single string.
#
# ## Section 13: Triple Quotes
#
# Python has a second trick for multi-line output: wrap your text in three single quotes (`'''`) or three double quotes (`"""`).
#
# ```python
# print('''My contact:
# Email: your_name@gmail.com
# Phone: +xx-1234-5678''')
# ```
#
# **Output:**
# ```
# My contact:
# Email: your_name@gmail.com
# Phone: +xx-1234-5678
# ```
#
# > *Advanced note:* Triple quotes preserve the line breaks exactly as you typed them — handy for anything with a fixed multi-line layout.
#
# ## Section 14: Debugging a Multi-Line String
#
# Time to put that to use. Here's the output we're after:
#
# ```
# To-Do List:
# 1. Complete Python exercise
# 2. Review coding concepts
# 3. Have a cuppa tea
# ```
#
# The code below is trying to get there and failing. Run it, read the error, then fix it.
#
# > *Hint:* Think about how Python expects a multi-line string to be written — `\n` or triple quotes will both get you there.
# > *Extension:* Once you've fixed it, write a second version using whichever trick you didn't use the first time.

# %%
print('''To-Do List:
1. Complete Python exercise
2. Review coding concepts
3. Have a cuppa tea''')
# Out:
# To-Do List:
# 1. Complete Python exercise
# 2. Review coding concepts
# 3. Have a cuppa tea

# %% [markdown]
# ## Section 15: Print a Python Poem
#
# Ask your AI assistant for a short (3–4 line) poem about Python, then print it using whichever technique you like best:
#
# - Multiple `print()` calls
# - `\n` inside one string
# - Triple quotes
#
# Match the line breaks exactly. For example, if your AI gives you:
#
# ```
# Python dances in lines of code,
# A rhythm where logic is bestowed.
# In every loop, a tale unfolds,
# A world of wonder in each node.
# ```
#
# ...your output should look exactly like that.
#
# > *Tip:* Pick a different technique from the one you used in Section 14, just for the practice.
#
# ## Section 16: Print a Personal Profile
#
# Now build a personal profile using a **single** `print()` call. Target output:
#
# ```
# Personal Profile:
# Name: Alice Smith
# Favourite Language: Python
# Hobby: Coding and bushwalking
# ```
#
# > *Note:* You've still got three options (multiple prints, `\n`, triple quotes) — try one you haven't used yet in this notebook.
#
# ## Section 17: Comments
#
# One last thing before you go: the line of code the computer *never* runs.
#
# A comment doesn't affect your program at all, but it explains what's going on to any human reading it — including future-you. In Python, anything after a `#` on a line is ignored by the computer.
#
# ```python
# # This line is a comment and won't be executed
# print("Do you have any comment?")
# ```
#
# **Output:**
# ```
# Do you have any comment?
# ```
#
# > *Quick question:* Which symbol tells Python to ignore a line?
#
# ## Section 18: Writing Good Comments
#
# Anna has just learned everything covered in this notebook and written a short script to show it off:
#
# ```python
# print("Hello, World!")
# print()
# print("This is the first line. \nThis is the second line.")
# print('''Three quotes can be used also
# to print multiple lines using a single print function''')
# ```
#
# She wants to add three comments explaining what's happening, one above each relevant line:
#
# - `print()` on its own leaves a blank line
# - `\n` tells Python to start a new line
# - Triple quotes can also print multiple lines
#
# **Your task:** Add Anna's three comments in the right places.
#
# ```python
# print("Hello, World!")
#
# print()
#
# print("This is the first line. \nThis is the second line.")
#
# print('''Three quotes can be used also
# to print multiple lines using a single print function''')
# ```
#
# Clear, readable code is the first habit that separates "code that works" from "code someone else can maintain." You've now got both.

# %%
print("Hello, World!")
#print() on its own leaves a blank line
print()
#\n tells Python to start a new line
print("This is the first line. \nThis is the second line.")
#Triple quotes can also print multiple lines
print('''Three quotes can be used also
to print multiple lines using a single print function''')

# %%
print("Python, a language, clear and grand,\nWith elegant syntax, easy to command.\nFrom data's depths to web's domain,\nIt helps us build, again and again.")
# Out:
# Python, a language, clear and grand,
#  With elegant syntax, easy to command.
# From data's depths to web's domain,
# It helps us build, again and again.

# %%
print("Python, a language, clear and grand, \nWith elegant syntax, easy to command. \nFrom data's depths to web's domain, \nIt helps us build, again and again.")
# Out:
# python, a language, clear and grand,
# With elegant syntax, easy to command.
# From data's depths to web's domain,
# It helps us build, again and again.

# %%
print("Personal Profile")
print("Name: Lily")
print("Favourite language: Python")
print("Hobby: Coding and bushwalking")
# Out:
# Personal Profile
# Name: Lily
# Favourite language: Python
# Hobby: Coding and bushwalking
